# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/4_didactica_aritmetica/blob/main/evaluation/exposicion_1_aula_invertida_aritmetica/trabajo_1_grupo_1/trabajo_1_grupo_1_Merlis_Francisco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Primer video de apoyo a la enseñanza de la trigonometría desde el modelo de flipped classroom]()

# %% [markdown]
# Estudiantes a cargo:
#
# - Grupo 1:
#
#   * Merlis Julieth
#   * Fancisco Javier:
#
# Contenido asignado es Trigonometría:
#
# * Las funciones seno para modelación de fenómenos periódicos o
# * **Graficación e interpretación de las funciones seno**(Este es el elegido).
# * Sistema de medición angular sexagesimal.
# La unidad de medición es el grado
# * Solo considerar los ángulos especilas:
#
# $$ \{ 0^{o}, 30^{o}, 45, 60, 90, 180, 270, 360\} $$
#
# * Contrucción de la función  seno a partir de la circunferencia unitaria y la rotación de un punto sobre la circunferencia y el triángulo que este punto determina.

# %% [markdown]
# ## Modelo de [Flipped Classroom](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Classroom o clase invertida es un enfoque pedagógico en el que la instrucción directa se realiza fuera del aula y se utiliza el tiempo de clase
# para llevar a cabo actividades que impliquen el
# desarrollo de procesos cognitivos de mayor
# complejidad, en las que son necesarias la ayuda y la
# experiencia del/la docente.

# %% [markdown]
# ## Finalidad
#
# Mejora el proceso de enseñanza-aprendizaje realizando, fuera del aula, actividades de aprendizaje sencillas
#
#
# * observar,
# * memorizar,
# * resumir, etc.
#
# y, en el aula, actividades más complejas
#
# * razonar,
# * examinar,
# * priorizar,
# * argumentar,
# * proponer, etc.
#
# que requieren la interacción entre iguales y la ayuda del/la docente como persona facilitadora.

# %% [markdown]
# # Clase de Trigonometría bajo el modelo de Pedagogía Invertida

# %% [markdown]
# Funciones trigonométricas página 62 del [Stewart](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=IS13MZ)

# %% [markdown]
# # Función seno

# %% [markdown]
# La trigonometría y las funciones trigonométricas se repasan en la página de referencia 2 y también en el apéndice D.

# %% [markdown]
# En cálculo, por convención, siempre se utilizan medidas en radianes (excepto cuando se indique lo contrario).

# %% [markdown]
# Por ejemplo, cuando se utiliza la función $f(x) = sen \ x$, se sobreentiende que $sen x$ significa el seno de un ángulo cuya medida en radianes es $x$. Así, las gráficas de las funciones seno y coseno son como se muestra en la figura 18.

# %% [markdown]
# <img src = ''>

# %%
import numpy as np
import matplotlib.pyplot as plt 

x = np.linspace(-2*np.pi, 4*np.pi, 200)
y = np.sin(x)
plt.plot(x,y)
plt.title(r'Función $y = \sin(x)$')

plt.grid(alpha = 0.6)

plt.show()

# %% [markdown]
# ## Cuestionario
#
# * Qué es triangulo rectángulko
# * circunferencia unitaria
# * Qué es un ámngulo
# * cuáles son los ángulos notables
# * conocer las equivalencias entre las representaciones fraccionarias y decimales de algunos numeros racionales.

# %% [markdown]
# ## Descripción verbal de la función seno
#
# * tiene periodo:
# * es creciente en los intervalos de la forma:
# * es decreciente en los intervalos de la forma:
# * su rango es acotado en el intervalo:
# * pasa por el origen, es decir, $(0,0) \in \{(x,f(x)) \mid x \in \mathbb{R}\}$

# %% [markdown]
# # La función coseno

# %%
import numpy as np
import matplotlib.pyplot as plt 
dominio = [-2*np.pi, 4*np.pi]
x = np.linspace(dominio[0], dominio[1], 200)
y = np.cos(x)
plt.plot(x,y, 'b-')
plt.title(r'Función $y = \cos(x)$')

plt.plot([dominio[0], dominio[1]], [0,0], 'g-') # gráfico del eje horizontal
plt.plot([0,0], [-1.1,1.1], 'g-') # gráfico del eje vertical


plt.grid(alpha = 0.6)

plt.savefig('función_coseno.jpg')

plt.show()

# %% [markdown]
# ## Descripción verbal de la función coseno
#
# * tiene periodo:
# * es creciente en los intervalos de la forma:
# * es decreciente en los intervalos de la forma:
# * su rango es acotado en el intervalo:
# * no pasa por el origen, es decir, $(0,0) \notin \{(x,\cos(x)) \mid x \in \mathbb{R}\}$. Más precisamente, su intersecto con el eje vertical es el punto $y = 1$.

# %% [markdown]
# ## Tareas para realizar en clase

# %% [markdown]
# ## Tareas para realizar fuera de clase

# %% [markdown]
# ## Cuestionario
#
# 1. ¿A qué se la llama flipped classroom?
# 2. ¿Qué diferencias encuentras en la función seno y la función coseno?

# %% [markdown]
# ## Referentes
#
# * [Stewart](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=jaEbhW) Apendice D de Stewart sobre trigonoimetría Pásgina 845.
