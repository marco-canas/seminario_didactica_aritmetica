# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/drive/1x9_RQ8DFPHtdQteoGBrwRKQSdnAajulh"_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)
#
# ## Definición y características de este modelo

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Learning o aprendizaje invertido es un enfoque pedagógico en el que:
#
# * la instrucción directa se realiza fuera del aula y
# * se utiliza el tiempo de clase para llevar a cabo actividades que impliquen el desarrollo de procesos cognitivos de mayor complejidad, en las que son necesarias la ayuda y la experiencia del docente.

# %% [markdown]
# ## ¿Para qué sirve?
#
# Mejora el proceso de enseñanza-aprendizaje realizando,
#
# * fuera del aula, actividades de aprendizaje sencillas (observar, memorizar, resumir, etc.) y,
# * en el aula, actividades más complejas (razonar, examinar, priorizar, argumentar, proponer, etc.) que requieren la interacción entre iguales y la ayuda del docente como facilitador.

# %% [markdown]
# <img src = ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Fomento de la lectura literaria asociada a licenciatura en Matemáticas
#
#
#  [El hombre que claculaba, Malba Tahan](http://www.librosmaravillosos.com/hombrecalculaba/pdf/El%20Hombre%20que%20Calculaba%20-%20Malba%20Tahan.pdf)
#
# [El diablo de los números, Hans Magnus Enzensberger](http://www.librosmaravillosos.com/eldiablodelosnumeros/pdf/El%20diablo%20de%20los%20numeros%20-%20Hans%20Magnus%20Enzensberger.pdf)

# %% [markdown]
# ### Objetivo de aprendizaje
#
# *  Identificar la potenciación y la radicación para representar situaciones matemáticas con números enteros.

# %% [markdown]
# ## prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
# 1. Operaciones básicas de la aritmética(suma, resta, multiplicación y división)
# 2. Operaciones básicas de la aritmética en los enteros.

# %% [markdown]
# La potenciación es una operación matemática que representa la multiplicación repetida de un número llamado base por sí mismo, un número determinado de veces. Se utiliza la notación exponente para expresar una potencia. En una potencia, la base es elevada a un exponente y el resultado se obtiene multiplicando la base por sí misma tantas veces como indique el exponente. Por ejemplo, en la expresión $2^3$, el número 2 es la base y el número 3 es el exponente. El resultado de esta potencia es 2 × 2 × 2 = 8.
#
# La radicación, por otro lado, es la operación inversa de la potenciación. Permite encontrar el número que, elevado a cierto exponente, resulta en un valor dado. En términos más simples, la radicación encuentra la raíz de un número. El símbolo de la raíz es √. Por ejemplo, la raíz cuadrada de 9 (√9) es 3, ya que 3 elevado al cuadrado es igual a 9. Además de la raíz cuadrada, existen otros tipos de raíces, como la raíz cúbica $(∛)$ o la raíz n-ésima $(∛n)$.

# %% [markdown]
# [Propiedades de la potenciación](https://lasmatesfaciles.com/2019/03/08/propiedades-de-la-potenciacion/)
#
#
# [Propiedades de la radicación](http://contenidosdigitales.ulp.edu.ar/exe/matematica1/propiedades_de_la_radicacin.html)

# %% [markdown]
# ## Tereas para realizar antes de la clase

# %% [markdown]
# 1. Ver los videos respectivos [Potenciación en $E$](https://youtu.be/fsyWnIfFtkw) [Propiedades de la potenciación](https://youtu.be/tA94S33kxm8)
# 2. Memorizar las definiciones [Potenciación](https://guao.org/sites/default/files/Potenciaci%C3%B3n%20de%20N%C3%BAmeros%20Enteros_0.pdf) [Radicacion en $E$](http://contenidosdigitales.ulp.edu.ar/exe/matematica1/radicacin_de_un_nmero_entero.html)

# %% [markdown]
# # Tareas para realizar en clase

# %% [markdown]
# * Comprende los conceptos de potenciación y radicación en $Z$
# * Realiza ejercicios de potenciación y radicación trabajando en equipos.

# %% [markdown]
# [Realiza este test en equipo](https://docs.google.com/forms/d/e/1FAIpQLSdxY4_CPqfDX3g_d4MRM1H-GRhMGiDHY5Cl9unAkC_tiwFwCA/viewform?usp=sf_link)

# %% [markdown]
# # Tareas para realizar después de la realización de la clase

# %% [markdown]
# * Actividades de memorización:
#   - Mira videos sobre el tema. [Video de refuerzo](https://youtu.be/JgmZO3q7sE8)
#   - relectura de notas.
#   - ejercicios de mayor complejidad.

# %% [markdown]
# ## Dificultades de aprendizaje detectados durante la clase
#
#
#
# * Comprender que cualquier número diferente de cero elevado a la potencia $0$ es = $1$

# %% [markdown]
# # Vocabulario
#
# Potenciación: es una operación que consiste en multiplicar por sí mismo un número principal llamado base, tantas veces como lo indique otro número que se llama exponente.
#
# Exponente: Los exponentes son una forma de expresar la multiplicación de una expresión por sí misma un número determinado de veces. La letra a es conocida como la base, el número que usted va a multiplicar, y a la letra n se le llama potencia o exponente, el cual indica la cantidad de veces que va a multiplicar a.
#
# Potencia: Es es resultado de multiplicar un numero x, n veces por el mismo.
#
# Radicación: la radicación es la forma como se expresa que un número debe multiplicarse por sí mismo, la cantidad de veces que otro número se lo indique, para obtener un valor exacto de esta operación.
#
#
# Inverso: La potencia de un número distinto de 0 elevado al número negativo
# −n es el inverso del número elevado a n.
#
# La raíz: es el número que debe multiplicarse por sí mismo, las veces que el índice se lo indique.
#
# El radicando: es el resultado de la operación entre índice y raíz.

# %% [markdown]
# ## Mapa conceptual que vincula los conceptos asoaciados al objetivo de aprendizaje
#
# ![p2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### [Evaluamos al profesor Fred y Manuel, aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje](https://docs.google.com/forms/d/e/1FAIpQLSfh-YMBU6aIwsaiqxM5yPPsZ7p-6TpM9K4dQPCGmi9F9dKXvQ/viewform?usp=share_link)

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido.
#
# 1. Es importante pensar que el modelo de aula invertida no está del todo desarrollado debido a que en los sectores más vulnerables de la población no hay un acceso garantizado al uso de las nuevas tecnologías y por ende este modelo pedagógico no está al alcance de todos los estudiantes, aún falta reflexión y es lo que se busca día a día.
#
#
# ### Agradecimientos
#
# Agradezco a Dios por ser bueno con nosotros y por permitirnos el día de hoy estar vivos.

# %% [markdown]
# ## Referencias
#
# * [stewart precálculo]()
# * [matematicas simplificadas]()
# * [Potenciación y radicación]()

# %%
import math

def verificar_igualdad(base, exponente):
    resultado_potencia = base ** exponente
    raiz = math.sqrt(resultado_potencia)
    
    if raiz == base:
        print("La igualdad es verdadera.")
    else:
        print("La igualdad es falsa.")

# Ejemplo de uso
verificar_igualdad(3, 2)  # Comprobando la igualdad entre la base 3 y la raíz cuadrada de 3^2
# Out:
# La igualdad es verdadera.

# %%
def potenciacion(base, exponente):
    resultado = base ** exponente
    return resultado

base = float(input("Ingrese la base: "))
exponente = int(input("Ingrese el exponente: "))

resultado = potenciacion(base, exponente)
print("El resultado de la potenciación es:", resultado)

# %%
import math

def radicacion(numero, indice):
    resultado = numero ** (1 / indice)
    return resultado

numero = float(input("Ingrese el númer: "))
indice = int(input("Ingrese el índice de la raíz: "))

resultado = radicacion(numero, indice)
print("El resultado de la radicación es:", resultado)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1957176392ea> in <cell line: 7>()
#       5     return resultado
#       6
# ----> 7 numero = float(input("Ingrese el númer: "))
#       8 indice = int(input("Ingrese el índice de la raíz: "))
#       9
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
